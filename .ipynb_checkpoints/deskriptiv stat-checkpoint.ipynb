# %%
import pandas as pd
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 

df=pd.read_csv('house_data_final.csv')

# %%
df.hist(bins=50, figsize=(20,15))
# Out:
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000028E78D37850>,
# ...
#       dtype=object)

# %%
df['price'].describe()
# Out:
# count    5.209300e+04
# mean     2.257958e+06
# std      2.431229e+06
# min      0.000000e+00
# 25%      8.950000e+05
# 50%      1.645000e+06
# 75%      2.795000e+06
# max      8.500000e+07
# Name: price, dtype: float64

# %%
df['rooms'].describe()
# Out:
# count    52093.000000
# mean         4.130390
# std          2.268657
# min          0.000000
# 25%          3.000000
# 50%          4.000000
# 75%          5.000000
# max         56.000000
# Name: rooms, dtype: float64

# %%
df['squaremeterPrice'].describe()
# Out:
# count    5.209300e+04
# mean     1.630685e+04
# std      2.643841e+04
# min      0.000000e+00
# 25%      6.706000e+03
# 50%      1.241100e+04
# 75%      2.138800e+04
# max      3.750000e+06
# Name: squaremeterPrice, dtype: float64

# %%
df['size'].describe()
# Out:
# count    52093.000000
# mean       128.527077
# std        123.639303
# min          0.000000
# 25%         83.000000
# 50%        125.000000
# 75%        168.000000
# max      15830.000000
# Name: size, dtype: float64

# %%
df['price'].describe()

# %%
df['daysForSale'].describe()
# Out:
# count    52093.000000
# mean       314.074655
# std        477.903478
# min          0.000000
# 25%         54.000000
# 50%        146.000000
# 75%        372.000000
# max       4981.000000
# Name: daysForSale, dtype: float64

# %%
print(df[["price","size","squaremeterPrice","rooms","daysForSale"]].describe().to_latex())
# Out:
# \begin{tabular}{lrrrrr}
# \toprule
# {} &         price &          size &  squaremeterPrice &         rooms &   daysForSale \\
# \midrule
# count &  5.209300e+04 &  52093.000000 &      5.209300e+04 &  52093.000000 &  52093.000000 \\
# mean  &  2.257958e+06 &    128.527077 &      1.630685e+04 &      4.130390 &    314.074655 \\
# std   &  2.431229e+06 &    123.639303 &      2.643841e+04 &      2.268657 &    477.903478 \\
# min   &  0.000000e+00 &      0.000000 &      0.000000e+00 &      0.000000 &      0.000000 \\
# 25\%   &  8.950000e+05 &     83.000000 &      6.706000e+03 &      3.000000 &     54.000000 \\
# 50\%   &  1.645000e+06 &    125.000000 &      1.241100e+04 &      4.000000 &    146.000000 \\
# 75\%   &  2.795000e+06 &    168.000000 &      2.138800e+04 &      5.000000 &    372.000000 \\
# max   &  8.500000e+07 &  15830.000000 &      3.750000e+06 &     56.000000 &   4981.000000 \\
# \bottomrule
# \end{tabular}

# %%
print("\\begin{tabular}{lrrrrr}\n\\toprule\n{} &         price &          size &  squaremeterPrice &         rooms &  daysForSale \\\\\n\\midrule\ncount &  4.745400e+04 &  47454.000000 &      4.745400e+04 &  47454.000000 &  47454.00000 \\\\\nmean  &  2.403192e+06 &    140.114005 &      1.782128e+04 &      4.524053 &    277.74784 \\\\\nstd   &  2.474908e+06 &     91.991557 &      2.716816e+04 &      1.966962 &    428.08410 \\\\\nmin   &  0.000000e+00 &      0.000000 &      0.000000e+00 &      0.000000 &      0.00000 \\\\\n25\\%   &  1.045000e+06 &     95.000000 &      8.201000e+03 &      3.000000 &     50.00000 \\\\\n50\\%   &  1.795000e+06 &    131.000000 &      1.355550e+04 &      4.000000 &    133.00000 \\\\\n75\\%   &  2.995000e+06 &    172.000000 &      2.261600e+04 &      5.000000 &    335.00000 \\\\\nmax   &  8.500000e+07 &   9073.000000 &      3.750000e+06 &     56.000000 &   4981.00000 \\\\\n\\bottomrule\n\\end{tabular}
")
# Out:
#   File "<ipython-input-3-38524373b3e9>", line 1
#     print("\\begin{tabular}{lrrrrr}\n\\toprule\n{} &         price &          size &  squaremeterPrice &         rooms &  daysForSale \\\\\n\\midrule\ncount &  4.745400e+04 &  47454.000000 &      4.745400e+04 &  47454.000000 &  47454.00000 \\\\\nmean  &  2.403192e+06 &    140.114005 &      1.782128e+04 &      4.524053 &    277.74784 \\\\\nstd   &  2.474908e+06 &     91.991557 &      2.716816e+04 &      1.966962 &    428.08410 \\\\\nmin   &  0.000000e+00 &      0.000000 &      0.000000e+00 &      0.000000 &      0.00000 \\\\\n25\\%   &  1.045000e+06 &     95.000000 &      8.201000e+03 &      3.000000 &     50.00000 \\\\\n50\\%   &  1.795000e+06 &    131.000000 &      1.355550e+04 &      4.000000 &    133.00000 \\\\\n75\\%   &  2.995000e+06 &    172.000000 &      2.261600e+04 &      5.000000 &    335.00000 \\\\\nmax   &  8.500000e+07 &   9073.000000 &      3.750000e+06 &     56.000000 &   4981.00000 \\\\\n\\bottomrule\n\\end{tabular}
# ...
